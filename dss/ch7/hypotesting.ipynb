# %%
import sqlalchemy as sa
import os
from dotenv import load_dotenv


load_dotenv()

db_pass = os.get_env("POSTGRES_PASSWORD")

engine = sa.create_engine(f"postgresql+psycopg2://datasci:{db_pass}@localhost:5432/datasci")

df.to_sql("my_table", engine, if_exists="replace", index=False)  # pandas → postgres

# %% [markdown]
# ssh -f -N -L 5432:localhost:5432 you@host
#
# ps aux | grep "5432:localhost:5432"
# kill <pid>
